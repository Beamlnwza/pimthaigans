# %%
import os
# %load_ext autoreload
# %autoreload 2

from src.Helper.Folder_Remove import remove_all_in_folder
from src.Visual.plot import Plotter

# %%
data_path = '../../PimthaiGANS-Dataset/data'

# %%
img_plot = Plotter(data_path)

# %%
check_index = 0
img_plot.plot_88(index=check_index)

# %%
for i in os.listdir(data_path):
     remove_all_in_folder(os.path.join(data_path, i))
# Out:
# ../../PimthaiGANS-Dataset/data\00 is empty
# ../../PimthaiGANS-Dataset/data\01 is empty
# ../../PimthaiGANS-Dataset/data\02 is empty
# ../../PimthaiGANS-Dataset/data\03 is empty
# ../../PimthaiGANS-Dataset/data\04 is empty
# ../../PimthaiGANS-Dataset/data\05 is empty
# ../../PimthaiGANS-Dataset/data\06 is empty
# ../../PimthaiGANS-Dataset/data\07 is empty
# ../../PimthaiGANS-Dataset/data\08 is empty
# ../../PimthaiGANS-Dataset/data\09 is empty
# ../../PimthaiGANS-Dataset/data\10 is empty
# ../../PimthaiGANS-Dataset/data\11 is empty
# ../../PimthaiGANS-Dataset/data\12 is empty
# ../../PimthaiGANS-Dataset/data\13 is empty
# ../../PimthaiGANS-Dataset/data\14 is empty
# ../../PimthaiGANS-Dataset/data\15 is empty
# ../../PimthaiGANS-Dataset/data\16 is empty
# ../../PimthaiGANS-Dataset/data\17 is empty
# ../../PimthaiGANS-Dataset/data\18 is empty
# ../../PimthaiGANS-Dataset/data\19 is empty
# ../../PimthaiGANS-Dataset/data\20 is empty
# ../../PimthaiGANS-Dataset/data\21 is empty
# ...
